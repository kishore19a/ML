# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd

# import plotly
import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# make regression dataset
X, y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1 ,noise=50)

# %%
df = pd.DataFrame({'x1': X[:,0], 'x2': X[:,1], 'y': y})
df.head()
# Out:
#          x1        x2          y
# 0 -1.008163  1.450475 -54.749524
# 1 -1.218538  0.013723 -78.210890
# 2 -0.374048  0.760096  17.820158
# 3 -0.489367  1.295073 -66.475932
# 4 -0.705479 -0.391709 -34.209823

# %%
# plot the data
fig = px.scatter_3d(df, x='x1', y='x2', z='y', opacity=0.7)
fig.show()

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
# import the model
from sklearn.linear_model import LinearRegression
# create the model
model = LinearRegression()
# fit the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
# get error metrics
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('R2 Score:', r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 1551.722774408385
# Mean Absolute Error: 31.730520952460115
# R2 Score: 0.7515189849572116

# %%
print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
# Out:
# Intercept: -3.2457235017280652
# Coefficients: [51.75678184 32.70093468]

# %%
# draw the regression hyperplane
fig = px.scatter_3d(df, x='x1', y='x2', z='y', opacity=0.7)
fig.add_trace(go.Scatter3d(x=[-2, 2], y=[-2, 2], z=[model.intercept_ + model.coef_[0] * -2 + model.coef_[1] * -2, model.intercept_ + model.coef_[0] * 2 + model.coef_[1] * 2], mode='lines', line=dict(color='red', width=3)))
fig.show()
